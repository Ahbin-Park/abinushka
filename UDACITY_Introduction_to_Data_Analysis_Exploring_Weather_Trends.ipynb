# %% [markdown]
# <a href="https://colab.research.google.com/github/Ahbin-Park/abinushka/blob/main/UDACITY_Introduction_to_Data_Analysis_Exploring_Weather_Trends.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
import pandas as pd
tem_moscow = pd.read_csv('/content/drive/MyDrive/tem_moscow.csv', index_col=0)
tem_johannesburg = pd.read_csv('/content/drive/MyDrive/tem_johannesburg.csv', index_col=0)
tem_seoul = pd.read_csv('/content/drive/MyDrive/tem_seoul.csv', index_col=0)
tem_world = pd.read_csv('/content/drive/MyDrive/tem_world.csv', index_col=0)

# %%
tem_moscow.head()
# Out:
#         city country  avg_temp
# year
# 1743  Moscow  Russia     -2.57
# 1744  Moscow  Russia      6.64
# 1745  Moscow  Russia     -6.13
# 1746  Moscow  Russia       NaN
# 1747  Moscow  Russia       NaN

# %%
tem_seoul.head()
# Out:
#        city      country  avg_temp
# year
# 1839  Seoul  South Korea      9.47
# 1840  Seoul  South Korea     10.21
# 1841  Seoul  South Korea      9.44
# 1842  Seoul  South Korea     10.13
# 1843  Seoul  South Korea     10.33

# %%
tem_world.head()
# Out:
#       avg_temp
# year
# 1750      8.72
# 1751      7.98
# 1752      5.78
# 1753      8.39
# 1754      8.47

# %%
#difference check
tem_seoul['difference_world'] = tem_seoul['avg_temp'] - tem_world['avg_temp']
tem_seoul.head()
# Out:
#        city      country  avg_temp  difference_world
# year
# 1839  Seoul  South Korea      9.47              1.84
# 1840  Seoul  South Korea     10.21              2.41
# 1841  Seoul  South Korea      9.44              1.75
# 1842  Seoul  South Korea     10.13              2.11
# 1843  Seoul  South Korea     10.33              2.16

# %%
tem_seoul.plot(kind='line')

# %%
tem_world.plot(kind='line')

# %%
tem_moscow.plot(kind='line')

# %%
tem_johannesburg.plot(kind='line')

# %%
sma_30d_tem_seoul = tem_seoul.rolling(window=30).mean()

# %%
plot_sma_30d_tem_seoul = sma_7d_tem_seoul.plot(kind='line')
plot_sma_7d_tem_seoul.set_title('Average temperature trend of Seoul')
plot_sma_7d_tem_seoul.set_xlabel('year')
plot_sma_7d_tem_seoul.set_ylabel('average temperature')
# Out:
# Text(17.200000000000003, 0.5, 'average temperature')

# %%
sma_7d_tem_world = tem_world.rolling(window=7).mean()

# %%
plot_sma_7d_tem_world = sma_7d_tem_world.plot(kind='line')
plot_sma_7d_tem_world.set_title('Average temperature trend of world')
plot_sma_7d_tem_world.set_xlabel('year')
plot_sma_7d_tem_world.set_ylabel('average temperature')
# Out:
# Text(0, 0.5, 'average temperature')

# %%
sma_7d_tem_moscow = tem_moscow.rolling(window=7).mean()

# %%
sma_7d_tem_johannesburg = tem_johannesburg.rolling(window=7).mean()

# %%
sma_7d_tem_seoul.plot(kind= 'line')

# %%
sma_7d_tem_world.plot(kind= 'line')

# %%
import seaborn as sns

# %%
sns.lineplot(x='year', y='avg_temp', data=sma_7d_tem_seoul, label = 'Seoul')
sns.lineplot(x='year', y='avg_temp', data=sma_7d_tem_world, label = 'World')

plt.title('Average Temperature Trend')
plt.xlabel('year')
plt.ylabel('temperature')
plt.show()

# %%
sns.lineplot(x='year', y='avg_temp', data=sma_7d_tem_seoul, label = 'Seoul')
sns.lineplot(x='year', y='avg_temp', data=sma_7d_tem_moscow, label = 'Moscow')
sns.lineplot(x='year', y='avg_temp', data=sma_7d_tem_johannesburg, label = 'Johannesburg')
sns.lineplot(x='year', y='avg_temp', data=sma_7d_tem_world, label = 'World')

plt.title('Average Temperature Trend')
plt.xlabel('ear')
plt.ylabel('avgerage temperature')
plt.legend(loc='upper left', bbox_to_anchor=(1.04, 0.3))
plt.show()
